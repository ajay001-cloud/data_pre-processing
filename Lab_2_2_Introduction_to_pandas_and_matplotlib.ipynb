# %% [markdown]
# <a href="https://colab.research.google.com/github/ajay001-cloud/data_pre-processing/blob/learn/Lab_2_2_Introduction_to_pandas_and_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# In this tutorial, we have primarily introduced pandas and the various kinds of
# operations it supports along with some basic plotting with the help of matplotlib
#
# The contents of this tutorials are as follows:
#
# 1. Introduction to Pandas and its common usages
# 2. Loading a dataset file into memory and
# 3. Common ways to create DataFrame and Series
# 4. Different ways to access DataFrame and Series
# 5. Data Transformation in Pandas
# 8. Data Visualization using Matplotlib

# %%
# Download the dataset file to local storage to current directory (from publicly
# shared drive file)
#
# Original source:
# https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques
#
# !gdown 1Yhw8tBCmjYrDZ5Rm1xPrP2y5bmBmxoEP
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Yhw8tBCmjYrDZ5Rm1xPrP2y5bmBmxoEP
# To: /content/housing.csv
# 100% 461k/461k [00:00<00:00, 86.4MB/s]

# %%
# 1. Introduction to Pandas and its common usages

# %%
# Pandas is a data manipulation and analysis library used very popularly and
# extensively used for common oading, cleaning, manipulation and exploration
# tasks.
#
# Data Cleaning: It helps you handle messy data, such as filling or removing
# missing values (NaN), and correcting inconsistent data types.
#
# Data Exploration: You can use it to get a quick summary of your data,
# calculate statistics, and filter, sort, and select specific subsets of data.
#
# Data Transformation: It allows you to reshape your data, merge multiple
# datasets together, and perform complex operations by applying custom functions
# to your data.
#
# Reading and Writing Data: Pandas can read data from and write data to various
# file formats, including CSV, Excel, SQL databases, and JSON. This makes it an
# excellent tool for ingesting data from different sources.
#
# We import the 'pandas' package as 'pd' to follow the common convention
#
# We'll learn more about the different usages of this library in the labs ahead
import pandas as pd

# %%
# 2. Loading a dataset file into memory for further use

# %%
# We'll now be using pandas to load our dataset file into memory.
#
# Pandas has primarily supports two data structures that almost always used
# together, unless the latter is used separately.
#
# DataFrame: A 2D table-like data structure with labelled rows and columns.
# It can be viewed as a collection of Series data strucutres with row labels.
#
# Series: A 1D labelled array with single column and multiple rows (index/label)
# that holds elements of a given type
#
# The type could be any from int64, float64, bool, datetime64[ns],
# timedelta64[ns], category (ns -> nanoseconds) or the generic object type.
#
# Both these data structures are mutable in terms of their size and data and
# the library provides extensive for simple to complicated operations for any
# combination of structures.
#
# Some operations could lead to a new DataFrame/Series, so always try reading
# the docs while/before using a method/operator to avoid debugging frustrations
# in general.
#
# In the below code, we're trying to load the present in the downloaded dataset
# into a pandas dataframe using the read_csv function of pandas library.
#
# Note: df is a name commonly used to store a reference of the main dataframe
DATASET_PATH = "./housing.csv"
df = pd.read_csv(DATASET_PATH)
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# 3. Common ways to create DataFrame and Series

# %%
# There are multiple other ways of instantiating a Series and DataFrame

# Series

# Create a pandas Series from a Python list
list_data = [10, 20, 30, 40, 50]
series_from_list = pd.Series(list_data)
print("Series from list:")
print(series_from_list)

print("\n")

# Create a pandas Series from a Python dictionary
dict_data = {'a': 100, 'b': 200, 'c': 300, 'd': 400}
series_from_dict = pd.Series(dict_data)
print("Series from dictionary:")
print(series_from_dict)

print("\n")

# DataFrame
# (Note: The row count of each column should be the same always)

# Create a simple DataFrame from a Python dictionary
data = {
    'Column 1': [1, 2, 3, 4],
    'Column 2': ['A', 'B', 'C', 'D'],
    'Column 3': [True, False, True, False]
}
df_from_dict = pd.DataFrame(data)

# Display the created DataFrame
print("DataFrame created from a dictionary:\n")
df_from_dict
# Out:
# Series from list:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
#
#
# Series from dictionary:
# a    100
# b    200
# c    300
# d    400
# dtype: int64
#
#
# DataFrame created from a dictionary:
#    Column 1 Column 2  Column 3
# 0         1        A      True
# 1         2        B     False
# 2         3        C      True
# 3         4        D     False

# %%
# 4. Different ways to access DataFrame and Series

# %%
# Accessing and displaying elements in Series

# By Index
print("Accessing element by index position (first element from list series):")
print(series_from_list[0])

print("\n")

# By row label
print("Accessing element by label (element with label 'b' from dictionary series):")
print(series_from_dict['b'])

print("\n")

# Performing a basic
# Self-learning: Explore other possible operations on dataframes
series_added = series_from_list + 5
print("Series after adding 5:")
print(series_added)
# Out:
# Accessing element by index position (first element from list series):
# 10
#
#
# Accessing element by label (element with label 'b' from dictionary series):
# 200
#
#
# Series after adding 5:
# 0    15
# 1    25
# 2    35
# 3    45
# 4    55
# dtype: int64

# %%
# Accessing and displaying rows in DataFrame

# Display the first 7 rows of the DataFrame
print("First 7 rows of the DataFrame:")
display(df.head(7))

# Display the last 3 rows of the DataFrame
print("\nLast 3 rows of the DataFrame:")
display(df.tail(3))

# Print a concise summary of the DataFrame
print("\nConcise summary of the DataFrame:")
df.info()

# Generate descriptive statistics of numerical columns
print("\nDescriptive statistics of numerical columns:")
display(df.describe())

# Print the dimensions of the DataFrame
print("\nShape of the DataFrame (rows, columns):")
print(df.shape)
# Out:
# First 7 rows of the DataFrame:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
# Accessing and displaying columns/series pr in DataFrame

# Selecting a single column using square brackets []
print("Selecting a single column ('SalePrice'):")
sale_price_column = df['SalePrice']
display(sale_price_column.head()) # Display first few rows as the Series is long

print("\n")

# Selecting multiple columns using a list of column names within square brackets []
print("Selecting multiple columns (['SalePrice', 'OverallQual', 'GrLivArea']):")
multiple_columns = df[['SalePrice', 'OverallQual', 'GrLivArea']]
display(multiple_columns.head()) # Display first few rows

print("\n")

# Selecting a row by its index label using .loc
print("Selecting row with index label 0 using .loc:")
row_by_label = df.loc[0]
display(row_by_label)

print("\n")

# Selecting multiple rows by their index labels using a list of index labels with .loc
print("Selecting rows with index labels [0, 5, 10] using .loc:")
multiple_rows_by_label = df.loc[[0, 5, 10]]
display(multiple_rows_by_label)

print("\n")

# Selecting a specific cell (row and column) using .loc
print("Selecting cell at row index label 0 and column 'SalePrice' using .loc:")
cell_by_label = df.loc[0, 'SalePrice']
print(cell_by_label)

print("\n")

# Selecting a row by its integer position using .iloc
print("Selecting row at integer position 0 using .iloc:")
row_by_iloc = df.iloc[0]
display(row_by_iloc)

print("\n")

# Selecting multiple rows by their integer positions using a list of integer positions with .iloc
print("Selecting rows at integer positions [0, 5, 10] using .iloc:")
multiple_rows_by_iloc = df.iloc[[0, 5, 10]]
display(multiple_rows_by_iloc)

print("\n")

# Selecting a specific cell (row and column) using .iloc
print("Selecting cell at integer position (0, 80) using .iloc:") # Column 80 is 'SalePrice' (0-indexed)
cell_by_iloc = df.iloc[0, 80]
print(cell_by_iloc)

print("\n")

# Selecting a slice of rows and columns using .loc
#
# Select rows from index label 5 to 10 and columns 'SalePrice' to
#c'SaleCondition' (inclusive for both)
print("Selecting slice of rows (label 5 to 10) and columns (label 'SalePrice' to 'SaleCondition') using .loc:")
slice_by_loc = df.loc[5:10, 'SalePrice':'SaleCondition']
display(slice_by_loc)

print("\n")

# Selecting a slice of rows and columns using .iloc
#
# Select rows from integer position 5 to 10 (exclusive of 10) and columns from integer position 70 to 75 (exclusive of 75)
print("Selecting slice of rows (iloc 5 to 10) and columns (iloc 70 to 75) using .iloc:")
slice_by_iloc = df.iloc[5:10, 70:75]
display(slice_by_iloc)
# Out:
# Selecting a single column ('SalePrice'):
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64
# Selecting multiple columns (['SalePrice', 'OverallQual', 'GrLivArea']):
#    SalePrice  OverallQual  GrLivArea
# 0     208500            7       1710
# 1     181500            6       1262
# 2     223500            7       1786
# 3     140000            7       1717
# 4     250000            8       2198
# Selecting row with index label 0 using .loc:
# Id                    1
# MSSubClass           60
# MSZoning             RL
# LotFrontage        65.0
# LotArea            8450
#                   ...
# MoSold                2
# YrSold             2008
# SaleType             WD
# SaleCondition    Normal
# SalePrice        208500
# Name: 0, Length: 81, dtype: object
# Selecting rows with index labels [0, 5, 10] using .loc:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# ...

# %%
# Print the count of missing values for each column
print("Count of missing values per column:")
print(df.isnull().sum())
# Out:
# Count of missing values per column:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
# 5. Data Transformation in Pandas

# %%
# There are times when you want to transform the data present in a column/the
# rows of a DataFrame. Pandas offers different methods for data transformation

# Convert 'MSSubClass' column/series to object type as it represents categories
df['MSSubClass'] = df['MSSubClass'].astype(str)

# Display the data types again to show the change
print("\nData types after converting 'MSSubClass':")
print(df.dtypes)
# Out:
# Data types after converting 'MSSubClass':
# Id                 int64
# MSSubClass        object
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
# Define a function to convert square feet to square meters (1 sq ft = 0.092903 sq m)
def sqft_to_sqm(sqft):
    return sqft * 0.092903

# Apply the function to the 'LotArea' column and create a new column
df['LotArea_sqm'] = df['LotArea'].apply(sqft_to_sqm)

# Display the first few rows of the original and new columns
print("\nOriginal 'LotArea' and new 'LotArea_sqm' columns:")
display(df[['LotArea', 'LotArea_sqm']].head())
# Out:
# Original 'LotArea' and new 'LotArea_sqm' columns:
#    LotArea  LotArea_sqm
# 0     8450    785.03035
# 1     9600    891.86880
# 2    11250   1045.15875
# 3     9550    887.22365
# 4    14260   1324.79678

# %%
# Sort the DataFrame by 'SalePrice' in ascending order
df_sorted_asc = df.sort_values(by='SalePrice', ascending=True)

# Display the first few rows of the sorted DataFrame
print("\nDataFrame sorted by 'SalePrice' in ascending order:")
display(df_sorted_asc[['SalePrice', 'OverallQual', 'GrLivArea']].head())
# Out:
# DataFrame sorted by 'SalePrice' in ascending order:
#      SalePrice  OverallQual  GrLivArea
# 495      34900            4        720
# 916      35311            2        480
# 968      37900            3        968
# 533      39300            1        334
# 30       40000            4       1317

# %%
# Sort the DataFrame by 'SalePrice' in descending order
df_sorted_desc = df.sort_values(by='SalePrice', ascending=False)

# Display the first few rows of the sorted DataFrame
print("\nDataFrame sorted by 'SalePrice' in descending order:")
display(df_sorted_desc[['SalePrice', 'OverallQual', 'GrLivArea']].head())
# Out:
# DataFrame sorted by 'SalePrice' in descending order:
#       SalePrice  OverallQual  GrLivArea
# 691      755000           10       4316
# 1182     745000           10       4476
# 1169     625000           10       3627
# 898      611657            9       2364
# 803      582933            9       2822

# %%
# Filter the DataFrame for houses with SalePrice greater than 500000
filtered_df_price = df[df['SalePrice'] > 500000]

# Display the first few rows of the filtered DataFrame
print("\nDataFrame filtered for SalePrice > 500000:")
display(filtered_df_price.head())
# Out:
# DataFrame filtered for SalePrice > 500000:
#       Id MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 178  179         20       RL         63.0    17423   Pave   NaN      IR1
# 440  441         20       RL        105.0    15431   Pave   NaN      Reg
# 691  692         60       RL        104.0    21535   Pave   NaN      IR1
# 769  770         60       RL         47.0    53504   Pave   NaN      IR2
# 803  804         60       RL        107.0    13891   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolQC Fence MiscFeature MiscVal MoSold YrSold  \
# 178         Lvl    AllPub  ...    NaN   NaN         NaN       0      7   2009
# 440         Lvl    AllPub  ...    NaN   NaN         NaN       0      4   2009
# 691         Lvl    AllPub  ...    NaN   NaN         NaN       0      1   2007
# 769         HLS    AllPub  ...    NaN   NaN         NaN       0      6   2010
# 803         Lvl    AllPub  ...    NaN   NaN         NaN       0      1   2009
#
# ...

# %%
# Filter the DataFrame for houses with 'SalePrice' greater than 300000 AND
# 'OverallQual' greater than 8
filtered_df_multiple_conditions = df[(df['SalePrice'] > 300000) &
 (df['OverallQual'] > 8)]

# Display the first few rows of the filtered DataFrame
print("\nDataFrame filtered for SalePrice > 300000 AND OverallQual > 8:")
display(filtered_df_multiple_conditions.head())
# Out:
# DataFrame filtered for SalePrice > 300000 AND OverallQual > 8:
#       Id MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 11    12         60       RL         85.0    11924   Pave   NaN      IR1
# 45    46        120       RL         61.0     7658   Pave   NaN      Reg
# 53    54         20       RL         68.0    50271   Pave   NaN      IR1
# 58    59         60       RL         66.0    13682   Pave   NaN      IR2
# 161  162         60       RL        110.0    13688   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolQC Fence MiscFeature MiscVal MoSold YrSold  \
# 11          Lvl    AllPub  ...    NaN   NaN         NaN       0      7   2006
# 45          Lvl    AllPub  ...    NaN   NaN         NaN       0      2   2010
# 53          Low    AllPub  ...    NaN   NaN         NaN       0     11   2006
# 58          HLS    AllPub  ...    NaN   NaN         NaN       0     10   2006
# ...

# %%
# 6. DataFrame

# %%
# Grouping data is a fundamental operation in data analysis that allows you to
# split your data into groups based on some criteria, apply a function to each
# group independently, and then combine the results into a data structure.

# In pandas, this process is often referred to as the
# "split-apply-combine" strategy.

# The primary method for grouping in pandas is the `groupby()` method. One could
# apply various aggregation functions (like `mean()`, `sum()`, `count()`,
# `size()`, `min()`, `max()`, `std()`, `var()`, etc.) to the group.
# Pandas will then apply the chosen function to each group and combine the
# results into a new DataFrame or Series.

# You can group by a single column or multiple columns.

# Grouping by a single column ('OverallQual') and calculating the mean
# 'SalePrice'
print("Average sales price for a each quality rating:")
mean_price_by_quality = df.groupby('OverallQual')['SalePrice'].mean()
display(mean_price_by_quality)

print("\n")

# Grouping by multiple columns ('OverallQual' and 'BldgType')
print("Average sales price for a each quality rating and building type:")
mean_price_by_quality_and_bldgtype = df.groupby(['OverallQual', 'BldgType'])['SalePrice'].mean()
display(mean_price_by_quality_and_bldgtype)
# Out:
# Average sales price for a each quality rating:
# OverallQual
# 1      50150.000000
# 2      51770.333333
# 3      87473.750000
# 4     108420.655172
# 5     133523.347607
# 6     161603.034759
# 7     207716.423197
# 8     274735.535714
# 9     367513.023256
# 10    438588.388889
# Name: SalePrice, dtype: float64
# Average sales price for a each quality rating and building type:
# OverallQual  BldgType
# 1            1Fam         50150.000000
# 2            1Fam         51770.333333
# 3            1Fam         86285.937500
#              2fmCon       95000.000000
#              Duplex       91300.000000
# 4            1Fam        111014.300000
#              2fmCon      108343.750000
#              Duplex      109657.375000
#              Twnhs        85750.000000
#              TwnhsE       81750.000000
# 5            1Fam        133371.215339
#              2fmCon      135950.000000
#              Duplex      140121.838710
#              Twnhs       107833.333333
# ...

# %%
# Combining different datasets is a common task in data analysis. Pandas
# provides several ways to combine DataFrames, with merging being one of the
# most powerful and flexible. Merging allows you to combine DataFrames based on
# common columns or indices, similar to how you would join tables in a
# relational database.
#
# The primary function for merging DataFrames is pd.merge(). This function
# offers various types of merges, controlled by the how parameter:
#
# inner (default): Returns only the rows where the merge key(s) are present in
# both DataFrames. This is the intersection of the two DataFrames' keys.
#
# left: Returns all rows from the left DataFrame and the matched rows from the
# right DataFrame. Missing values (NaN) will appear in the columns from the
# right DataFrame for rows that don't have a match.
#
# right: Returns all rows from the right DataFrame and the matched rows from
# the left DataFrame. Missing values (NaN) will appear in the columns from the
# left DataFrame for rows that don't have a match.
#
# outer: Returns all rows when there is a match in either the left or the right
# DataFrame. This is the union of the two DataFrames' keys. Missing values (NaN)
# will appear where there is no match.
#
# Let's create two sample DataFrames and demonstrate these different merge types

# 1. Create two sample DataFrames
data1 = {'ID': [1, 2, 3, 4],
         'Name': ['Alice', 'Bob', 'Charlie', 'David'],
         'Age': [25, 30, 35, 40]}
df1 = pd.DataFrame(data1)

data2 = {'ID': [1, 3, 4, 5],
         'City': ['New York', 'London', 'Paris', 'Tokyo'],
         'Salary': [50000, 60000, 70000, 80000]}
df2 = pd.DataFrame(data2)

print("DataFrame 1:")
display(df1)

print("\nDataFrame 2:")
display(df2)

# 2. Perform an inner merge
print("\nInner Merge:")
inner_merge_df = pd.merge(df1, df2, on='ID', how='inner')
display(inner_merge_df)

# 3. Perform a left merge
print("\nLeft Merge:")
left_merge_df = pd.merge(df1, df2, on='ID', how='left')
display(left_merge_df)

# 4. Perform a right merge
print("\nRight Merge:")
right_merge_df = pd.merge(df1, df2, on='ID', how='right')
display(right_merge_df)

# 5. Perform an outer merge
print("\nOuter Merge:")
outer_merge_df = pd.merge(df1, df2, on='ID', how='outer')
display(outer_merge_df)
# Out:
# DataFrame 1:
#    ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   3  Charlie   35
# 3   4    David   40
# DataFrame 2:
#    ID      City  Salary
# 0   1  New York   50000
# 1   3    London   60000
# 2   4     Paris   70000
# 3   5     Tokyo   80000
# Inner Merge:
#    ID     Name  Age      City  Salary
# 0   1    Alice   25  New York   50000
# 1   3  Charlie   35    London   60000
# 2   4    David   40     Paris   70000
# Left Merge:
#    ID     Name  Age      City   Salary
# 0   1    Alice   25  New York  50000.0
# 1   2      Bob   30       NaN      NaN
# 2   3  Charlie   35    London  60000.0
# 3   4    David   40     Paris  70000.0
# Right Merge:
#    ID     Name   Age      City  Salary
# 0   1    Alice  25.0  New York   50000
# 1   3  Charlie  35.0    London   60000
# 2   4    David  40.0     Paris   70000
# 3   5      NaN   NaN     Tokyo   80000
# Outer Merge:
#    ID     Name   Age      City   Salary
# 0   1    Alice  25.0  New York  50000.0
# ...

# %%
# 7. Data Visualization using Matplotlib

# %%
# Matplotlib is a library that is compatible with pandas and is used for the
# purpose of data visualization
import matplotlib.pyplot as plt

# %%
# Create a scatter plot of 'GrLivArea' vs. 'SalePrice'
df.plot(kind='scatter', x='GrLivArea', y='SalePrice')

# Add a title to the scatter plot
plt.title('Sale Price vs. Above Ground Living Area')

# Add labels to the x and y axes
plt.xlabel('Above Ground Living Area (sq ft)')
plt.ylabel('Sale Price')

# Display the plot
plt.show()

# %%
# Create a histogram of the 'SalePrice' column
df['SalePrice'].hist()

# Add a title to the histogram
plt.title('Distribution of Sale Prices')
# Add a label to the x-axis and y-axis
plt.xlabel('Sale Price')
plt.ylabel('Frequency')

# Display the histogram
plt.show()
